# %% [markdown]
# # Introdução à Econometria
#
# Econometria é uma disciplina que combina economia, matemática e estatística para analisar dados econômicos. O objetivo principal da econometria é transformar dados teóricos em modelos quantitativos que possam ser testados empiricamente.
#
# ## Principais Conceitos
#
# - **Modelos Econométricos**: São representações matemáticas de relações econômicas. Eles ajudam a prever e explicar comportamentos econômicos.
# - **Regressão Linear**: Uma técnica comum usada para estimar a relação entre uma variável dependente e uma ou mais variáveis independentes.
# - **Teste de Hipóteses**: Utilizado para determinar se os resultados obtidos em uma amostra podem ser generalizados para a população inteira.
#
# ## Aplicações
#
# A econometria é amplamente utilizada em diversas áreas, como:
#
# - **Previsão**: Prever tendências futuras, como crescimento do PIB ou taxas de desemprego.
# - **Avaliação**: Analisar o impacto de políticas governamentais, como mudanças na taxa de juros ou programas de assistência social.
# - **Análises**: Estudar o comportamento dos consumidores e a dinâmica dos mercados financeiros.
#
# Através da econometria, economistas e analistas podem tomar decisões mais informadas e baseadas em dados concretos.

# %% [markdown]
# ### Bibliotecas Principais

# %%
# %pip install pandas matplotlib numpy seaborn statsmodels requests openpyxl pycountry fuzzywuzzy gdown
# Out:
# Requirement already satisfied: pandas in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (2.1.2)
# Requirement already satisfied: seaborn in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: statsmodels in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (0.14.4)
# Requirement already satisfied: requests in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: openpyxl in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (3.1.5)
# Requirement already satisfied: pycountry in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (24.6.1)
# Requirement already satisfied: fuzzywuzzy in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (0.18.0)
# Collecting gdown
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: et-xmlfile in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from openpyxl) (1.1.0)
# Collecting beautifulsoup4 (from gdown)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting tqdm (from gdown)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: six in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\guian\indicium\treinamentos\.venv\lib\site-packages (from tqdm->gdown) (0.4.6)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Installing collected packages: tqdm, soupsieve, PySocks, filelock, beautifulsoup4, gdown
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.12.3 filelock-3.16.1 gdown-5.2.0 soupsieve-2.6 tqdm-4.66.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização de dados
import matplotlib.pyplot as plt
import seaborn as sns

# Modelagem Econométrica
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Requisições HTTP
import requests
import gdown
import io

# Manipulação de palavras
from fuzzywuzzy import process
import pycountry

# %% [markdown]
# # O que é Econometria?
#
# Econometria é uma disciplina que combina economia, matemática e estatística para analisar dados econômicos. O objetivo principal da econometria é transformar dados teóricos em modelos quantitativos que possam ser testados empiricamente.
#
# ## Principais Conceitos para aplicar a Econometria em Python
#
# - **Modelos Econométricos**: São representações matemáticas de relações econômicas.
# Exemplo de modelo econométrico: $Y = \beta_0 + \beta_1X + \epsilon$
#
# - **Regressão Linear**: Uma técnica comum usada para estimar a relação entre uma variável dependente e uma ou mais variáveis independentes. Essa relação é vista no Beta, que é o coeficiente da variável independente.
#
# - **P-Value**: É um valor que ajuda a determinar a significância estatística de uma variável independente em um modelo de regressão. Quanto menor o p-valor, mais significativa é a variável.
#
# - **R²**: É uma medida de quão bem o modelo se ajusta aos dados. É quase como uma porcentagem que mostra o quanto a variável dependente é explicada pelas variáveis independentes.
#
# - **Tamaho da Amostra**: É a quantidade de observações disponíveis para análise. Quanto maior a amostra, mais confiável é o resultado.
#
# - **Resíduos**: São as diferenças entre os valores observados e os valores previstos pelo modelo. Eles são importantes para verificar a qualidade do ajuste do modelo.
#
# - **Desvio Padrão**: É uma medida de dispersão dos dados em torno da média. Quanto maior o desvio padrão, mais dispersos estão os dados.

# %% [markdown]
# ### Cross-Section Data

# %%
# URLs dos arquivos no Google Drive
url_rle = 'https://drive.google.com/uc?id=1eyl5SUhAQbvFTlScTtTLQdyoHmqj80zx'
url_gpdph = 'https://drive.google.com/uc?id=1vXudE9U22700oKk5xnpJdi5coPUizuKG'
url_inv = 'https://drive.google.com/uc?id=1tJ2NSvt_I7kOWAhrwodxKa3J_N_dsy_l' 

# Baixando os arquivos e lendo-os imediatamente com o pandas
df_rle = pd.read_csv(gdown.download(url_rle, quiet=False))
df_gpdph = pd.read_csv(gdown.download(url_gpdph, quiet=False))
df_inv = pd.read_excel(gdown.download(url_inv, quiet=False))
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1eyl5SUhAQbvFTlScTtTLQdyoHmqj80zx
# To: c:\Users\guian\Indicium\treinamentos\econometria-em-python\freedom-scores.csv
# 100%|██████████| 442k/442k [00:00<00:00, 4.52MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1vXudE9U22700oKk5xnpJdi5coPUizuKG
# To: c:\Users\guian\Indicium\treinamentos\econometria-em-python\labor-productivity-per-hour.csv
# 100%|██████████| 95.8k/95.8k [00:00<00:00, 1.69MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1tJ2NSvt_I7kOWAhrwodxKa3J_N_dsy_l
# To: c:\Users\guian\Indicium\treinamentos\econometria-em-python\Gross Fixed Capital Formation as a percentage of GDP.xlsx
# 100%|██████████| 162k/162k [00:00<00:00, 1.44MB/s]

# %%
df_rle
# Out:
#        Id         Name   Short Name ISO Code  Index Year  Overall Score  \
# 0       1  Afghanistan  Afghanistan       AF        2023            NaN
# 1       2      Albania      Albania       AL        2023           65.3
# 2       3      Algeria      Algeria       DZ        2023           43.2
# 3       4       Angola       Angola       AO        2023           53.0
# 4       5    Argentina    Argentina       AR        2023           51.0
# ...   ...          ...          ...      ...         ...            ...
# 5334  179   Venezuela     Venezuela       VE        1995           59.8
# 5335  180      Vietnam      Vietnam       VN        1995           41.7
# 5336  181        Yemen        Yemen       YE        1995           49.8
# 5337  182       Zambia       Zambia       ZM        1995           55.1
# 5338  183     Zimbabwe     Zimbabwe       ZW        1995           48.5
#
#       Property Rights  Judicial Effectiveness  Government Integrity  \
# 0                 5.8                     5.4                  12.7
# 1                55.9                    49.2                  35.5
# 2                27.8                    29.5                  28.4
# 3                41.1                    24.8                  22.9
# 4                34.6                    56.8                  42.8
# ...               ...                     ...                   ...
# 5334             50.0                     NaN                  10.0
# 5335             10.0                     NaN                  10.0
# 5336             30.0                     NaN                  10.0
# 5337             50.0                     NaN                  30.0
# 5338             50.0                     NaN                  30.0
#
#       Tax Burden  Government Spending  Fiscal Health  Business Freedom  \
# 0            NaN                  NaN            NaN              34.6
# 1           89.1                 71.0           58.2              70.7
# 2           71.9                 50.7           12.1              53.6
# 3           86.5                 86.9           85.1              41.6
# 4           66.9                 53.9           33.6              55.5
# ...          ...                  ...            ...               ...
# 5334        80.0                 76.1            NaN              85.0
# 5335        68.8                 87.1            NaN              40.0
# 5336        78.2                 73.4            NaN              70.0
# 5337        72.4                 74.8            NaN              55.0
# 5338        50.1                 65.3            NaN              55.0
#
#       Labor Freedom  Monetary Freedom  Trade Freedom  Investment Freedom  \
# 0              45.1               NaN            NaN                 NaN
# 1              49.7              81.3           82.8                70.0
# 2              51.4              75.1           57.5                30.0
# 3              53.9              58.9           64.8                30.0
# 4              55.1              36.5           61.2                55.0
# ...             ...               ...            ...                 ...
# 5334            NaN              52.0           65.0                50.0
# 5335            NaN              55.2           44.6                30.0
# 5336            NaN              41.8           45.0                70.0
# 5337            NaN              12.2           61.2                70.0
# 5338            NaN              54.7           51.8                30.0
#
#       Financial Freedom
# 0                   NaN
# 1                  70.0
# 2                  30.0
# 3                  40.0
# 4                  60.0
# ...                 ...
# 5334               70.0
# 5335               30.0
# 5336               30.0
# 5337               70.0
# 5338               50.0
#
# [5339 rows x 18 columns]

# %%
df_inv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                Indicator Name  Indicator Code       1960  \
# 0    Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS        NaN
# 1    Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS        NaN
# 2    Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS        NaN
# 3    Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS        NaN
# 4    Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS        NaN
# ..                                        ...             ...        ...
# 261  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS        NaN
# 262  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS        NaN
# 263  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  17.474796
# 264  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS        NaN
# 265  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  20.271267
#
#           1961       1962       1963       1964       1965  ...       2013  \
# 0          NaN        NaN        NaN        NaN        NaN  ...        NaN
# 1          NaN        NaN        NaN        NaN        NaN  ...  22.816759
# 2          NaN        NaN        NaN        NaN        NaN  ...        NaN
# 3          NaN        NaN        NaN        NaN        NaN  ...  18.120568
# 4          NaN        NaN        NaN        NaN        NaN  ...  26.158497
# ..         ...        ...        ...        ...        ...  ...        ...
# 261        NaN        NaN        NaN        NaN        NaN  ...  29.161155
# 262        NaN        NaN        NaN        NaN        NaN  ...        NaN
# 263  16.813354  16.191155  18.212305  19.742389  22.046063  ...  18.578712
# 264        NaN        NaN        NaN        NaN        NaN  ...  26.035908
# 265  18.439860  14.073199  12.734050  11.339980  11.748375  ...   9.181371
#
#           2014       2015       2016       2017       2018       2019  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1    24.253731  24.218215  23.456403  23.952357  20.993810  21.428638
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3    19.154326  18.951842  19.064122  17.581707  19.988446  23.153365
# 4    27.478813  28.209604  26.213214  23.242315  17.194699  16.237556
# ..         ...        ...        ...        ...        ...        ...
# 261  27.504805  28.267085  28.011597  29.959525  31.711269  31.042639
# 262        NaN        NaN        NaN        NaN        NaN        NaN
# 263  18.301199  18.008953  17.441504  16.398805  15.944577  15.417722
# 264  31.037455  38.453275  36.420591  38.808619  35.110120  35.756617
# 265   9.609292   9.995567   9.807839   9.663851  11.048306  10.699352
#
#           2020       2021  2022
# 0          NaN        NaN   NaN
# 1    20.750793  19.294592   NaN
# 2          NaN        NaN   NaN
# 3    24.015844  27.448714   NaN
# 4    19.565922  20.232049   NaN
# ..         ...        ...   ...
# 261  29.706191  32.880725   NaN
# 262        NaN        NaN   NaN
# 263  13.761791  13.091875   NaN
# 264  29.867508  28.913591   NaN
# 265  10.046081  12.399486   NaN
#
# [266 rows x 67 columns]

# %%
# Transformando os dados de df_inv em painel

df_inv = df_inv.melt(id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name='Year', value_name='Value')
df_inv.dropna(subset=['Value'], inplace=True)

# Ordenando os dados
df_inv = df_inv.sort_values(by=['Country Name', 'Year'])
df_inv
# Out:
#                       Country Name Country Code  \
# 7981   Africa Eastern and Southern          AFE
# 8247   Africa Eastern and Southern          AFE
# 8513   Africa Eastern and Southern          AFE
# 8779   Africa Eastern and Southern          AFE
# 9045   Africa Eastern and Southern          AFE
# ...                            ...          ...
# 15427                     Zimbabwe          ZWE
# 15693                     Zimbabwe          ZWE
# 15959                     Zimbabwe          ZWE
# 16225                     Zimbabwe          ZWE
# 16491                     Zimbabwe          ZWE
#
#                                  Indicator Name  Indicator Code  Year  \
# 7981   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1990
# 8247   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1991
# 8513   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1992
# 8779   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1993
# 9045   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1994
# ...                                         ...             ...   ...
# 15427  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2017
# 15693  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2018
# 15959  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2019
# 16225  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2020
# 16491  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2021
#
#            Value
# 7981   18.336239
# 8247   16.985092
# 8513   17.590785
# 8779   16.622941
# 9045   17.052206
# ...          ...
# 15427   9.663851
# 15693  11.048306
# 15959  10.699352
# 16225  10.046081
# 16491  12.399486
#
# [9800 rows x 6 columns]

# %%
df_gpdph
# Out:
#          Entity Code  Year  Productivity: output per hour worked
# 0     Argentina  ARG  1950                              3.727674
# 1     Argentina  ARG  1951                              3.752668
# 2     Argentina  ARG  1952                              3.365233
# 3     Argentina  ARG  1953                              3.522695
# 4     Argentina  ARG  1954                              3.623416
# ...         ...  ...   ...                                   ...
# 3487    Vietnam  VNM  2015                              4.946606
# 3488    Vietnam  VNM  2016                              5.156925
# 3489    Vietnam  VNM  2017                              5.652919
# 3490    Vietnam  VNM  2018                              5.982665
# 3491    Vietnam  VNM  2019                              6.739149
#
# [3492 rows x 4 columns]

# %%
# Função para encontrar o nome de país mais similar da lista oficial
def find_similar_country_name(name, official_country_names):
    best_match, score = process.extractOne(name, official_country_names)
    if score > 85:  # você pode ajustar este limite de acordo com suas necessidades
        return best_match
    return name  # retorna o nome original se a pontuação for baixa

# Lista de nomes de países corretos (você pode obtê-los de `pycountry`, por exemplo)
official_country_names = [country.name for country in pycountry.countries]

# Corrigindo os nomes de países no DataFrame

df_rle = df_rle.copy()
df_rle['Name'] = df_rle['Name'].apply(lambda name: find_similar_country_name(name, official_country_names))

df_gpdph = df_gpdph.copy()
df_gpdph['Entity'] = df_gpdph['Entity'].apply(lambda name: find_similar_country_name(name, official_country_names))

df_inv = df_inv.copy()
df_inv['Country Name'] = df_inv['Country Name'].apply(lambda name: find_similar_country_name(name, official_country_names))

# %%
df_rle.dropna()
df_gpdph.dropna()
df_inv.dropna()
# Out:
#                                        Country Name Country Code  \
# 7981   South Georgia and the South Sandwich Islands          AFE
# 8247   South Georgia and the South Sandwich Islands          AFE
# 8513   South Georgia and the South Sandwich Islands          AFE
# 8779   South Georgia and the South Sandwich Islands          AFE
# 9045   South Georgia and the South Sandwich Islands          AFE
# ...                                             ...          ...
# 15427                                      Zimbabwe          ZWE
# 15693                                      Zimbabwe          ZWE
# 15959                                      Zimbabwe          ZWE
# 16225                                      Zimbabwe          ZWE
# 16491                                      Zimbabwe          ZWE
#
#                                  Indicator Name  Indicator Code  Year  \
# 7981   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1990
# 8247   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1991
# 8513   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1992
# 8779   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1993
# 9045   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1994
# ...                                         ...             ...   ...
# 15427  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2017
# 15693  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2018
# 15959  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2019
# 16225  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2020
# 16491  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2021
#
#            Value
# 7981   18.336239
# 8247   16.985092
# 8513   17.590785
# 8779   16.622941
# 9045   17.052206
# ...          ...
# 15427   9.663851
# 15693  11.048306
# 15959  10.699352
# 16225  10.046081
# 16491  12.399486
#
# [9800 rows x 6 columns]

# %%
df_rle.rename(columns={'Index Year': 'Year'}, inplace=True)
df_rle
# Out:
#        Id                            Country   Short Name ISO Code  Year  \
# 0       1                        Afghanistan  Afghanistan       AF  2023
# 1       2                            Albania      Albania       AL  2023
# 2       3                            Algeria      Algeria       DZ  2023
# 3       4                             Angola       Angola       AO  2023
# 4       5                          Argentina    Argentina       AR  2023
# ...   ...                                ...          ...      ...   ...
# 5334  179  Venezuela, Bolivarian Republic of    Venezuela       VE  1995
# 5335  180                           Viet Nam      Vietnam       VN  1995
# 5336  181                              Yemen        Yemen       YE  1995
# 5337  182                             Zambia       Zambia       ZM  1995
# 5338  183                           Zimbabwe     Zimbabwe       ZW  1995
#
#       RLE_Score  Property Rights  Judicial Effectiveness  \
# 0           NaN              5.8                     5.4
# 1          65.3             55.9                    49.2
# 2          43.2             27.8                    29.5
# 3          53.0             41.1                    24.8
# 4          51.0             34.6                    56.8
# ...         ...              ...                     ...
# 5334       59.8             50.0                     NaN
# 5335       41.7             10.0                     NaN
# 5336       49.8             30.0                     NaN
# 5337       55.1             50.0                     NaN
# 5338       48.5             50.0                     NaN
#
#       Government Integrity  Tax Burden  Government Spending  Fiscal Health  \
# 0                     12.7         NaN                  NaN            NaN
# 1                     35.5        89.1                 71.0           58.2
# 2                     28.4        71.9                 50.7           12.1
# 3                     22.9        86.5                 86.9           85.1
# 4                     42.8        66.9                 53.9           33.6
# ...                    ...         ...                  ...            ...
# 5334                  10.0        80.0                 76.1            NaN
# 5335                  10.0        68.8                 87.1            NaN
# 5336                  10.0        78.2                 73.4            NaN
# 5337                  30.0        72.4                 74.8            NaN
# 5338                  30.0        50.1                 65.3            NaN
#
#       Business Freedom  Labor Freedom  Monetary Freedom  Trade Freedom  \
# 0                 34.6           45.1               NaN            NaN
# 1                 70.7           49.7              81.3           82.8
# 2                 53.6           51.4              75.1           57.5
# 3                 41.6           53.9              58.9           64.8
# 4                 55.5           55.1              36.5           61.2
# ...                ...            ...               ...            ...
# 5334              85.0            NaN              52.0           65.0
# 5335              40.0            NaN              55.2           44.6
# 5336              70.0            NaN              41.8           45.0
# 5337              55.0            NaN              12.2           61.2
# 5338              55.0            NaN              54.7           51.8
#
#       Investment Freedom  Financial Freedom
# 0                    NaN                NaN
# 1                   70.0               70.0
# 2                   30.0               30.0
# 3                   30.0               40.0
# 4                   55.0               60.0
# ...                  ...                ...
# 5334                50.0               70.0
# 5335                30.0               30.0
# 5336                70.0               30.0
# 5337                70.0               70.0
# 5338                30.0               50.0
#
# [5339 rows x 18 columns]

# %%
df_gpdph
# Out:
#          Entity Code  Year  Productivity: output per hour worked
# 0     Argentina  ARG  1950                              3.727674
# 1     Argentina  ARG  1951                              3.752668
# 2     Argentina  ARG  1952                              3.365233
# 3     Argentina  ARG  1953                              3.522695
# 4     Argentina  ARG  1954                              3.623416
# ...         ...  ...   ...                                   ...
# 3487   Viet Nam  VNM  2015                              4.946606
# 3488   Viet Nam  VNM  2016                              5.156925
# 3489   Viet Nam  VNM  2017                              5.652919
# 3490   Viet Nam  VNM  2018                              5.982665
# 3491   Viet Nam  VNM  2019                              6.739149
#
# [3492 rows x 4 columns]

# %%
df_inv
# Out:
#                                        Country Name Country Code  \
# 7981   South Georgia and the South Sandwich Islands          AFE
# 8247   South Georgia and the South Sandwich Islands          AFE
# 8513   South Georgia and the South Sandwich Islands          AFE
# 8779   South Georgia and the South Sandwich Islands          AFE
# 9045   South Georgia and the South Sandwich Islands          AFE
# ...                                             ...          ...
# 15427                                      Zimbabwe          ZWE
# 15693                                      Zimbabwe          ZWE
# 15959                                      Zimbabwe          ZWE
# 16225                                      Zimbabwe          ZWE
# 16491                                      Zimbabwe          ZWE
#
#                                  Indicator Name  Indicator Code  Year  \
# 7981   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1990
# 8247   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1991
# 8513   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1992
# 8779   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1993
# 9045   Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  1994
# ...                                         ...             ...   ...
# 15427  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2017
# 15693  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2018
# 15959  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2019
# 16225  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2020
# 16491  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  2021
#
#            Value
# 7981   18.336239
# 8247   16.985092
# 8513   17.590785
# 8779   16.622941
# 9045   17.052206
# ...          ...
# 15427   9.663851
# 15693  11.048306
# 15959  10.699352
# 16225  10.046081
# 16491  12.399486
#
# [9800 rows x 6 columns]

# %%
# Renomeia as colunas para uma melhor consistência
df_rle = df_rle.rename(columns={'Name': 'Country', 'Overall Score': 'RLE_Score'})
df_gpdph = df_gpdph.rename(columns={'Entity': 'Country', 'Productivity: output per hour worked': 'Productivity'})
df_inv = df_inv.rename(columns={'Country Name': 'Country', 'Value': 'INV_Score'})

# %%
# Une os DataFrames
df_rle['Year'] = df_rle['Year'].astype(str)
df_gpdph['Year'] = df_gpdph['Year'].astype(str)
df_inv['Year'] = df_inv['Year'].astype(str)

df_merged = df_rle.merge(df_gpdph, on=['Country', 'Year'], how='inner')
df_merged = df_merged.merge(df_inv, on=['Country', 'Year'], how='inner')

df_merged.drop_duplicates(subset=['Country', 'ISO Code'])

df_merged = df_merged.reset_index(drop=True)

df_merged
# Out:
#        Id                            Country     Short Name ISO Code  Year  \
# 0       5                          Argentina      Argentina       AR  2019
# 1       7                          Australia      Australia       AU  2019
# 2       8                            Austria        Austria       AT  2019
# 3      12                         Bangladesh     Bangladesh       BD  2019
# 4      15                            Belgium        Belgium       BE  2019
# ...   ...                                ...            ...      ...   ...
# 1627  174                     United Kingdom  UnitedKingdom       GB  1995
# 1628  175                      United States   UnitedStates       US  1995
# 1629  176                            Uruguay        Uruguay       UY  1995
# 1630  179  Venezuela, Bolivarian Republic of      Venezuela       VE  1995
# 1631  180                           Viet Nam        Vietnam       VN  1995
#
#       RLE_Score  Property Rights  Judicial Effectiveness  \
# 0          52.2             47.8                    44.5
# 1          80.9             79.1                    86.5
# 2          72.0             84.2                    71.3
# 3          55.6             36.1                    34.5
# 4          67.3             81.3                    61.6
# ...         ...              ...                     ...
# 1627       77.9             90.0                     NaN
# 1628       76.7             90.0                     NaN
# 1629       62.5             50.0                     NaN
# 1630       59.8             50.0                     NaN
# 1631       41.7             10.0                     NaN
#
#       Government Integrity  Tax Burden  ...  Monetary Freedom  Trade Freedom  \
# 0                     33.5        69.3  ...              60.2           70.0
# 1                     79.9        62.8  ...              86.6           87.6
# 2                     77.4        50.5  ...              81.5           86.0
# 3                     24.4        72.7  ...              69.9           63.6
# 4                     72.5        47.1  ...              76.1           86.0
# ...                    ...         ...  ...               ...            ...
# 1627                  90.0        61.3  ...              85.0           77.8
# 1628                  90.0        64.8  ...              83.8           78.4
# 1629                  50.0        84.6  ...              45.2           63.0
# 1630                  10.0        80.0  ...              52.0           65.0
# 1631                  10.0        68.8  ...              55.2           44.6
#
#       Investment Freedom  Financial Freedom  Code  Productivity  Country Code  \
# 0                   55.0               60.0   ARG     29.425880           ARG
# 1                   80.0               90.0   AUS     61.438488           AUS
# 2                   90.0               70.0   AUT     65.151680           AUT
# 3                   45.0               30.0   BGD      4.791032           BGD
# 4                   85.0               70.0   BEL     66.265240           BEL
# ...                  ...                ...   ...           ...           ...
# 1627                70.0               90.0   GBR     36.779327           GBR
# 1628                70.0               70.0   USA     49.044580           USA
# 1629                70.0               50.0   URY     16.467913           URY
# 1630                50.0               70.0   VEN     12.324745           VEN
# 1631                30.0               30.0   VNM      1.761117           VNM
#
#                                 Indicator Name  Indicator Code  INV_Score
# 0     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  14.199046
# 1     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  23.326927
# 2     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  24.913283
# 3     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  32.213730
# 4     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  24.279769
# ...                                        ...             ...        ...
# 1627  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  17.970711
# 1628  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  20.864599
# 1629  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  13.526948
# 1630  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  15.948856
# 1631  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  25.421159
#
# [1632 rows x 24 columns]

# %%
df_merged.to_csv('df_merged.csv', index=False)

# %%
df = pd.read_csv('df_merged.csv')
df
# Out:
#        Id                            Country     Short Name ISO Code  Year  \
# 0       5                          Argentina      Argentina       AR  2019
# 1       7                          Australia      Australia       AU  2019
# 2       8                            Austria        Austria       AT  2019
# 3      12                         Bangladesh     Bangladesh       BD  2019
# 4      15                            Belgium        Belgium       BE  2019
# ...   ...                                ...            ...      ...   ...
# 1627  174                     United Kingdom  UnitedKingdom       GB  1995
# 1628  175                      United States   UnitedStates       US  1995
# 1629  176                            Uruguay        Uruguay       UY  1995
# 1630  179  Venezuela, Bolivarian Republic of      Venezuela       VE  1995
# 1631  180                           Viet Nam        Vietnam       VN  1995
#
#       RLE_Score  Property Rights  Judicial Effectiveness  \
# 0          52.2             47.8                    44.5
# 1          80.9             79.1                    86.5
# 2          72.0             84.2                    71.3
# 3          55.6             36.1                    34.5
# 4          67.3             81.3                    61.6
# ...         ...              ...                     ...
# 1627       77.9             90.0                     NaN
# 1628       76.7             90.0                     NaN
# 1629       62.5             50.0                     NaN
# 1630       59.8             50.0                     NaN
# 1631       41.7             10.0                     NaN
#
#       Government Integrity  Tax Burden  ...  Monetary Freedom  Trade Freedom  \
# 0                     33.5        69.3  ...              60.2           70.0
# 1                     79.9        62.8  ...              86.6           87.6
# 2                     77.4        50.5  ...              81.5           86.0
# 3                     24.4        72.7  ...              69.9           63.6
# 4                     72.5        47.1  ...              76.1           86.0
# ...                    ...         ...  ...               ...            ...
# 1627                  90.0        61.3  ...              85.0           77.8
# 1628                  90.0        64.8  ...              83.8           78.4
# 1629                  50.0        84.6  ...              45.2           63.0
# 1630                  10.0        80.0  ...              52.0           65.0
# 1631                  10.0        68.8  ...              55.2           44.6
#
#       Investment Freedom  Financial Freedom  Code  Productivity  Country Code  \
# 0                   55.0               60.0   ARG     29.425880           ARG
# 1                   80.0               90.0   AUS     61.438488           AUS
# 2                   90.0               70.0   AUT     65.151680           AUT
# 3                   45.0               30.0   BGD      4.791032           BGD
# 4                   85.0               70.0   BEL     66.265240           BEL
# ...                  ...                ...   ...           ...           ...
# 1627                70.0               90.0   GBR     36.779327           GBR
# 1628                70.0               70.0   USA     49.044580           USA
# 1629                70.0               50.0   URY     16.467913           URY
# 1630                50.0               70.0   VEN     12.324745           VEN
# 1631                30.0               30.0   VNM      1.761117           VNM
#
#                                 Indicator Name  Indicator Code  INV_Score
# 0     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  14.199046
# 1     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  23.326927
# 2     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  24.913283
# 3     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  32.213730
# 4     Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  24.279769
# ...                                        ...             ...        ...
# 1627  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  17.970711
# 1628  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  20.864599
# 1629  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  13.526948
# 1630  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  15.948856
# 1631  Gross fixed capital formation (% of GDP)  NE.GDI.FTOT.ZS  25.421159
#
# [1632 rows x 24 columns]

# %% [markdown]
# ### Juntando tudo

# %%
df.columns
# Out:
# Index(['Id', 'Country', 'Short Name', 'ISO Code', 'Year', 'RLE_Score',
#        'Property Rights', 'Judicial Effectiveness', 'Government Integrity',
#        'Tax Burden', 'Government Spending', 'Fiscal Health',
#        'Business Freedom', 'Labor Freedom', 'Monetary Freedom',
#        'Trade Freedom', 'Investment Freedom', 'Financial Freedom', 'Code',
#        'Productivity', 'Country Code', 'Indicator Name', 'Indicator Code',
#        'INV_Score'],
#       dtype='object')

# %%
df = df.drop(columns=['Id', 'Short Name', 'ISO Code', 'Code', 'Country Code', 'Indicator Name', 'Indicator Code'])
df.dropna(inplace=True)

# substitiondo os espaços por _ em todas os nomes de colunas
df.columns = df.columns.str.replace(' ', '_')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')

## Mostrar só como ano
# df['Year'] = df['Year'].dt.year

# %%
## Mostrando dados de 2019
df[df['Year'] == '2019']
# Out:
#            Country       Year  RLE_Score  Property_Rights  \
# 0        Argentina 2019-01-01       52.2             47.8
# 1        Australia 2019-01-01       80.9             79.1
# 2          Austria 2019-01-01       72.0             84.2
# 3       Bangladesh 2019-01-01       55.6             36.1
# 4          Belgium 2019-01-01       67.3             81.3
# ..             ...        ...        ...              ...
# 61        Thailand 2019-01-01       68.3             53.7
# 62  United Kingdom 2019-01-01       78.9             92.3
# 63   United States 2019-01-01       76.8             79.3
# 64         Uruguay 2019-01-01       68.6             68.3
# 65        Viet Nam 2019-01-01       55.3             49.8
#
#     Judicial_Effectiveness  Government_Integrity  Tax_Burden  \
# 0                     44.5                  33.5        69.3
# 1                     86.5                  79.9        62.8
# 2                     71.3                  77.4        50.5
# 3                     34.5                  24.4        72.7
# 4                     61.6                  72.5        47.1
# ..                     ...                   ...         ...
# 61                    45.9                  36.4        81.3
# 62                    85.9                  83.8        64.7
# 63                    78.6                  77.4        75.1
# 64                    58.9                  69.2        77.2
# 65                    40.3                  34.0        79.7
#
#     Government_Spending  Fiscal_Health  Business_Freedom  Labor_Freedom  \
# 0                  49.5           33.0              56.4           46.9
# 1                  60.1           86.2              88.3           84.1
# 2                  24.5           85.5              74.9           68.7
# 3                  94.5           77.6              50.9           68.2
# 4                  15.2           73.4              78.1           61.0
# ..                  ...            ...               ...            ...
# 61                 85.8           96.5              82.5           63.9
# 62                 48.2           68.6              92.9           73.5
# 63                 57.1           53.1              83.8           89.4
# 64                 67.5           69.9              74.3           71.9
# 65                 74.1           40.7              63.5           62.8
#
#     Monetary_Freedom  Trade_Freedom  Investment_Freedom  Financial_Freedom  \
# 0               60.2           70.0                55.0               60.0
# 1               86.6           87.6                80.0               90.0
# 2               81.5           86.0                90.0               70.0
# 3               69.9           63.6                45.0               30.0
# 4               76.1           86.0                85.0               70.0
# ..               ...            ...                 ...                ...
# 61              75.2           83.0                55.0               60.0
# 62              81.2           86.0                90.0               80.0
# 63              76.6           86.6                85.0               80.0
# 64              72.9           78.6                85.0               30.0
# 65              68.9           79.2                30.0               40.0
#
#     Productivity  INV_Score
# 0      29.425880  14.199046
# 1      61.438488  23.326927
# 2      65.151680  24.913283
# 3       4.791032  32.213730
# 4      66.265240  24.279769
# ..           ...        ...
# 61     15.167234  22.567377
# 62     54.348810  17.852854
# 63     73.700400  20.978794
# 64     28.378277  15.404333
# 65      6.739149  30.362569
#
# [66 rows x 17 columns]

# %%
df_panel = df.copy()
df_panel.set_index(['Country', 'Year'], inplace=True)
df_panel
# Out:
#                            RLE_Score  Property_Rights  Judicial_Effectiveness  \
# Country        Year
# Argentina      2019-01-01       52.2             47.8                    44.5
# Australia      2019-01-01       80.9             79.1                    86.5
# Austria        2019-01-01       72.0             84.2                    71.3
# Bangladesh     2019-01-01       55.6             36.1                    34.5
# Belgium        2019-01-01       67.3             81.3                    61.6
# ...                              ...              ...                     ...
# Thailand       2017-01-01       66.2             51.3                    41.7
# United Kingdom 2017-01-01       76.4             93.8                    93.0
# United States  2017-01-01       75.1             81.3                    75.1
# Uruguay        2017-01-01       69.7             70.2                    66.8
# Viet Nam       2017-01-01       52.4             49.7                    32.0
#
#                            Government_Integrity  Tax_Burden  \
# Country        Year
# Argentina      2019-01-01                  33.5        69.3
# Australia      2019-01-01                  79.9        62.8
# Austria        2019-01-01                  77.4        50.5
# Bangladesh     2019-01-01                  24.4        72.7
# Belgium        2019-01-01                  72.5        47.1
# ...                                         ...         ...
# Thailand       2017-01-01                  40.7        81.0
# United Kingdom 2017-01-01                  78.3        65.1
# United States  2017-01-01                  78.1        65.3
# Uruguay        2017-01-01                  70.3        77.5
# Viet Nam       2017-01-01                  24.6        79.6
#
#                            Government_Spending  Fiscal_Health  \
# Country        Year
# Argentina      2019-01-01                 49.5           33.0
# Australia      2019-01-01                 60.1           86.2
# Austria        2019-01-01                 24.5           85.5
# Bangladesh     2019-01-01                 94.5           77.6
# Belgium        2019-01-01                 15.2           73.4
# ...                                        ...            ...
# Thailand       2017-01-01                 85.3           96.3
# United Kingdom 2017-01-01                 41.9           40.4
# United States  2017-01-01                 55.9           53.3
# Uruguay        2017-01-01                 69.4           77.2
# Viet Nam       2017-01-01                 74.6           21.1
#
#                            Business_Freedom  Labor_Freedom  Monetary_Freedom  \
# Country        Year
# Argentina      2019-01-01              56.4           46.9              60.2
# Australia      2019-01-01              88.3           84.1              86.6
# Austria        2019-01-01              74.9           68.7              81.5
# Bangladesh     2019-01-01              50.9           68.2              69.9
# Belgium        2019-01-01              78.1           61.0              76.1
# ...                                     ...            ...               ...
# Thailand       2017-01-01              69.9           62.8              72.9
# United Kingdom 2017-01-01              89.9           72.8              85.0
# United States  2017-01-01              84.4           91.0              80.1
# Uruguay        2017-01-01              74.8           62.9              71.3
# Viet Nam       2017-01-01              61.2           62.2              76.0
#
#                            Trade_Freedom  Investment_Freedom  \
# Country        Year
# Argentina      2019-01-01           70.0                55.0
# Australia      2019-01-01           87.6                80.0
# Austria        2019-01-01           86.0                90.0
# Bangladesh     2019-01-01           63.6                45.0
# Belgium        2019-01-01           86.0                85.0
# ...                                  ...                 ...
# Thailand       2017-01-01           82.8                50.0
# United Kingdom 2017-01-01           87.0                90.0
# United States  2017-01-01           87.1                80.0
# Uruguay        2017-01-01           80.6                85.0
# Viet Nam       2017-01-01           83.1                25.0
#
#                            Financial_Freedom  Productivity  INV_Score
# Country        Year
# Argentina      2019-01-01               60.0     29.425880  14.199046
# Australia      2019-01-01               90.0     61.438488  23.326927
# Austria        2019-01-01               70.0     65.151680  24.913283
# Bangladesh     2019-01-01               30.0      4.791032  32.213730
# Belgium        2019-01-01               70.0     66.265240  24.279769
# ...                                      ...           ...        ...
# Thailand       2017-01-01               60.0     14.745839  23.108365
# United Kingdom 2017-01-01               80.0     54.676918  18.123815
# United States  2017-01-01               70.0     71.638570  20.648162
# Uruguay        2017-01-01               30.0     28.295845  16.342017
# Viet Nam       2017-01-01               40.0      5.652919  30.544763
#
# [198 rows x 15 columns]

# %%
df_cross = df[df['Year'] == '2019']
df_cross
# Out:
#            Country       Year  RLE_Score  Property_Rights  \
# 0        Argentina 2019-01-01       52.2             47.8
# 1        Australia 2019-01-01       80.9             79.1
# 2          Austria 2019-01-01       72.0             84.2
# 3       Bangladesh 2019-01-01       55.6             36.1
# 4          Belgium 2019-01-01       67.3             81.3
# ..             ...        ...        ...              ...
# 61        Thailand 2019-01-01       68.3             53.7
# 62  United Kingdom 2019-01-01       78.9             92.3
# 63   United States 2019-01-01       76.8             79.3
# 64         Uruguay 2019-01-01       68.6             68.3
# 65        Viet Nam 2019-01-01       55.3             49.8
#
#     Judicial_Effectiveness  Government_Integrity  Tax_Burden  \
# 0                     44.5                  33.5        69.3
# 1                     86.5                  79.9        62.8
# 2                     71.3                  77.4        50.5
# 3                     34.5                  24.4        72.7
# 4                     61.6                  72.5        47.1
# ..                     ...                   ...         ...
# 61                    45.9                  36.4        81.3
# 62                    85.9                  83.8        64.7
# 63                    78.6                  77.4        75.1
# 64                    58.9                  69.2        77.2
# 65                    40.3                  34.0        79.7
#
#     Government_Spending  Fiscal_Health  Business_Freedom  Labor_Freedom  \
# 0                  49.5           33.0              56.4           46.9
# 1                  60.1           86.2              88.3           84.1
# 2                  24.5           85.5              74.9           68.7
# 3                  94.5           77.6              50.9           68.2
# 4                  15.2           73.4              78.1           61.0
# ..                  ...            ...               ...            ...
# 61                 85.8           96.5              82.5           63.9
# 62                 48.2           68.6              92.9           73.5
# 63                 57.1           53.1              83.8           89.4
# 64                 67.5           69.9              74.3           71.9
# 65                 74.1           40.7              63.5           62.8
#
#     Monetary_Freedom  Trade_Freedom  Investment_Freedom  Financial_Freedom  \
# 0               60.2           70.0                55.0               60.0
# 1               86.6           87.6                80.0               90.0
# 2               81.5           86.0                90.0               70.0
# 3               69.9           63.6                45.0               30.0
# 4               76.1           86.0                85.0               70.0
# ..               ...            ...                 ...                ...
# 61              75.2           83.0                55.0               60.0
# 62              81.2           86.0                90.0               80.0
# 63              76.6           86.6                85.0               80.0
# 64              72.9           78.6                85.0               30.0
# 65              68.9           79.2                30.0               40.0
#
#     Productivity  INV_Score
# 0      29.425880  14.199046
# 1      61.438488  23.326927
# 2      65.151680  24.913283
# 3       4.791032  32.213730
# 4      66.265240  24.279769
# ..           ...        ...
# 61     15.167234  22.567377
# 62     54.348810  17.852854
# 63     73.700400  20.978794
# 64     28.378277  15.404333
# 65      6.739149  30.362569
#
# [66 rows x 17 columns]

# %% [markdown]
# ### Começando com o simples

# %% [markdown]
# ### Modelo Econométrico
#
# O modelo econométrico estimado é o seguinte:
#
# $$
# \text{Productivity} = \beta_0 + \beta_1 \times \text{Government\_Integrity} + \epsilon
# $$

# %%
df_cross.columns
# Out:
# Index(['Country', 'Year', 'RLE_Score', 'Property_Rights',
#        'Judicial_Effectiveness', 'Government_Integrity', 'Tax_Burden',
#        'Government_Spending', 'Fiscal_Health', 'Business_Freedom',
#        'Labor_Freedom', 'Monetary_Freedom', 'Trade_Freedom',
#        'Investment_Freedom', 'Financial_Freedom', 'Productivity', 'INV_Score'],
#       dtype='object')

# %%
# Definidno a variável dependente e independente
X = df['Government_Integrity']
y = df['Productivity']

# Adicionando constante
X = sm.add_constant(X)

# Ajustando o modelo
model = sm.OLS(y, X).fit()

# Sumário do modelo
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Productivity   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.599
# Method:                 Least Squares   F-statistic:                     295.7
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):           5.24e-41
# Time:                        10:38:14   Log-Likelihood:                -823.94
# No. Observations:                 198   AIC:                             1652.
# Df Residuals:                     196   BIC:                             1658.
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  -10.9159      3.047     -3.582      0.000     -16.925      -4.906
# Government_Integrity     0.8920      0.052     17.196      0.000       0.790       0.994
# ==============================================================================
# Omnibus:                       28.601   Durbin-Watson:                   2.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.541
# Skew:                           0.815   Prob(JB):                     3.51e-10
# Kurtosis:                       4.619   Cond. No.                         161.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
## Para quem gosta de R, usando formula para ajustar o modelo

formula = 'Productivity ~ Government_Integrity'

model = smf.ols(formula=formula, data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Productivity   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.599
# Method:                 Least Squares   F-statistic:                     295.7
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):           5.24e-41
# Time:                        10:38:26   Log-Likelihood:                -823.94
# No. Observations:                 198   AIC:                             1652.
# Df Residuals:                     196   BIC:                             1658.
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept              -10.9159      3.047     -3.582      0.000     -16.925      -4.906
# Government_Integrity     0.8920      0.052     17.196      0.000       0.790       0.994
# ==============================================================================
# Omnibus:                       28.601   Durbin-Watson:                   2.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.541
# Skew:                           0.815   Prob(JB):                     3.51e-10
# Kurtosis:                       4.619   Cond. No.                         161.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Adicionando mais variáveis

# %%
df_cross.columns
# Out:
# Index(['Country', 'Year', 'RLE_Score', 'Property_Rights',
#        'Judicial_Effectiveness', 'Government_Integrity', 'Tax_Burden',
#        'Government_Spending', 'Fiscal_Health', 'Business_Freedom',
#        'Labor_Freedom', 'Monetary_Freedom', 'Trade_Freedom',
#        'Investment_Freedom', 'Financial_Freedom', 'Productivity', 'INV_Score'],
#       dtype='object')

# %% [markdown]
# $$
# \text{Productivity} = \beta_0 + \beta_1 \times \text{RLE\_Score} +
#
# \beta_2 \times \text{Property\_Rights} + \beta_3 \times \text{Judicial\_Effectiveness} + \beta_4 \times \text{Government\_Integrity} + \beta_5 \times \text{Tax\_Burden} + \beta_6 \times \text{Government\_Spending} + \beta_7 \times \text{Fiscal\_Health} + \beta_8 \times \text{Business\_Freedom} + \beta_9 \times \text{Labor\_Freedom} + \beta_{10} \times \text{Monetary\_Freedom} + \beta_{11} \times \text{Trade\_Freedom} + \beta_{12} \times \text{Investment\_Freedom} + \beta_{13} \times \text{Financial\_Freedom} + \beta_{14} \times \text{INV\_Score} + \epsilon
# $$

# %%
# Definidno a variável dependente e independente
X = df[['RLE_Score', 'Property_Rights',
       'Judicial_Effectiveness', 'Government_Integrity', 'Tax_Burden',
       'Government_Spending', 'Fiscal_Health', 'Business_Freedom',
       'Labor_Freedom', 'Monetary_Freedom', 'Trade_Freedom',
       'Investment_Freedom', 'Financial_Freedom', 'INV_Score']]
y = df['Productivity']

# Adicionando constante
X = sm.add_constant(X)

# Ajustando o modelo
model = sm.OLS(y, X).fit()

# Sumário do modelo
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Productivity   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     47.08
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):           5.28e-53
# Time:                        10:39:32   Log-Likelihood:                -763.88
# No. Observations:                 198   AIC:                             1558.
# Df Residuals:                     183   BIC:                             1607.
# Df Model:                          14
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      2.7408      7.996      0.343      0.732     -13.034      18.516
# RLE_Score                 -8.4407     29.226     -0.289      0.773     -66.103      49.222
# Property_Rights            0.8381      2.464      0.340      0.734      -4.024       5.700
# Judicial_Effectiveness     0.7919      2.434      0.325      0.745      -4.011       5.595
# Government_Integrity       1.0598      2.431      0.436      0.663      -3.737       5.857
# Tax_Burden                 0.4454      2.451      0.182      0.856      -4.390       5.280
# Government_Spending        0.5230      2.436      0.215      0.830      -4.284       5.330
# Fiscal_Health              0.6792      2.439      0.278      0.781      -4.133       5.491
# Business_Freedom           0.7193      2.450      0.294      0.769      -4.114       5.552
# Labor_Freedom              0.6379      2.435      0.262      0.794      -4.167       5.443
# Monetary_Freedom           0.0960      2.438      0.039      0.969      -4.715       4.907
# Trade_Freedom              1.0779      2.436      0.442      0.659      -3.729       5.885
# Investment_Freedom         1.1629      2.432      0.478      0.633      -3.636       5.962
# Financial_Freedom          0.7380      2.430      0.304      0.762      -4.056       5.532
# INV_Score                  0.8322      0.171      4.863      0.000       0.495       1.170
# ==============================================================================
# Omnibus:                       56.108   Durbin-Watson:                   2.251
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              161.550
# Skew:                           1.176   Prob(JB):                     8.31e-36
# Kurtosis:                       6.749   Cond. No.                     8.83e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.83e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Ganhamos aviso de multicolinearidade, e agora?
#
# ### O que é Multicolinearidade?
#
# Multicolinearidade é um fenômeno em que duas ou mais variáveis independentes em um modelo de regressão linear são altamente correlacionadas entre si. Isso pode levar a problemas de instabilidade numérica e dificultar a interpretação dos coeficientes estimados.
#
# ### Como lidar com a Multicolinearidade?
#
# 1. **Use o teste de VIF**: O fator de inflação da variância (VIF) é uma medida que indica o grau de multicolinearidade entre as variáveis independentes. Valores de VIF acima de 10 são considerados problemáticos.
#
# 2. **Veja quais variáveis estão com VIF alto**: Identifique as variáveis com VIF alto e considere removê-las do modelo. (Um numero base de corte é 12)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = df[[
    'RLE_Score'
    , 'Property_Rights'
    , 'Judicial_Effectiveness'
    , 'Government_Integrity'
    , 'Tax_Burden'
    , 'Government_Spending'
    , 'Fiscal_Health'
    , 'Business_Freedom'
    , 'Labor_Freedom'
    , 'Monetary_Freedom'
    , 'Trade_Freedom'
    , 'Investment_Freedom'
    , 'Financial_Freedom'
    , 'INV_Score'
    ]]

# Adicionando constante
X = sm.add_constant(X)

# Calculando o VIF para cada variável independente
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

vif_data
# Out:
#                    feature            VIF
# 0                    const      89.045585
# 1                RLE_Score  159599.239374
# 2          Property_Rights    2453.440986
# 3   Judicial_Effectiveness    3053.351673
# 4     Government_Integrity    3761.798891
# 5               Tax_Burden    1777.237568
# 6      Government_Spending    4925.034933
# 7            Fiscal_Health    4980.086448
# 8         Business_Freedom    1925.598195
# 9            Labor_Freedom    1492.386157
# 10        Monetary_Freedom    1168.063107
# 11           Trade_Freedom    1198.544918
# 12      Investment_Freedom    3710.326554
# 13       Financial_Freedom    2758.315725
# 14               INV_Score       1.265289

# %% [markdown]
# $$
# \text{Productivity} = \beta_0 + \beta_1 \times \text{Government\_Integrity} + \beta_2 \times \text{Government\_Spending} + \beta_3 \times \text{Investment\_Freedom} + \beta_4 \times \text{INV\_Score} + \epsilon
# $$

# %%
X = df[['Government_Integrity', 'Government_Spending', 'Investment_Freedom', 'INV_Score']]

X = sm.add_constant(X)

y = df['Productivity']

# Ajustando o modelo
model = sm.OLS(y, X).fit()

# Sumário do modelo
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Productivity   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     147.8
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):           1.27e-57
# Time:                        11:01:27   Log-Likelihood:                -776.18
# No. Observations:                 198   AIC:                             1562.
# Df Residuals:                     193   BIC:                             1579.
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  -11.9144      5.703     -2.089      0.038     -23.163      -0.665
# Government_Integrity     0.5150      0.057      9.040      0.000       0.403       0.627
# Government_Spending     -0.3622      0.040     -9.060      0.000      -0.441      -0.283
# Investment_Freedom       0.3449      0.056      6.208      0.000       0.235       0.455
# INV_Score                0.8400      0.168      4.988      0.000       0.508       1.172
# ==============================================================================
# Omnibus:                       45.891   Durbin-Watson:                   2.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.122
# Skew:                           1.023   Prob(JB):                     1.22e-24
# Kurtosis:                       6.027   Cond. No.                         700.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
## Novo teste de VIF

vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

vif_data
# Out:
#                 feature        VIF
# 0                 const  42.202229
# 1  Government_Integrity   1.923693
# 2   Government_Spending   1.235586
# 3    Investment_Freedom   1.803195
# 4             INV_Score   1.140861

# %% [markdown]
# ## Ok, funcionou! E agora?
#
# ### Teste de Heterocedasticidade

# %%
### Teste visual de heterocedasticidade

#### Visualizado a dispersão dos resíduos em gráfico de dispersão
residuals = model.resid
fitted = model.fittedvalues

plt.scatter(fitted, residuals)
plt.xlabel('Valores ajustados')
plt.ylabel('Resíduos')
plt.axhline(y=0, color='red', linewidth=1)
plt.title('Dispersão dos resíduos')
plt.show()

# %% [markdown]
# ## O que é Heterocedasticidade?
#
# Heterocedasticidade é um fenômeno em que a variância dos resíduos de um modelo de regressão não é constante em relação às variáveis independentes. Isso pode levar a estimativas de coeficientes imprecisas e testes de hipóteses inválidos. Em outras palavras, a variabilidade dos erros não segue uma distribuição normal.
#
# ### Temos um problema de heterocedasticidade, e agora?
#
# 1. **Transforme as variáveis**: Considere transformar as variáveis dependentes ou independentes para corrigir a heterocedasticidade.
#
# 2. **Use métodos robustos**: Utilize métodos de regressão robustos que são menos sensíveis à heterocedasticidade.

# %%
## Usando robustez para corrigir a heterocedasticidade
model = sm.OLS(y, X).fit(cov_type='HC3')
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Productivity   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     137.8
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):           2.01e-55
# Time:                        10:54:27   Log-Likelihood:                -776.18
# No. Observations:                 198   AIC:                             1562.
# Df Residuals:                     193   BIC:                             1579.
# Df Model:                           4
# Covariance Type:                  HC3
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  -11.9144     11.807     -1.009      0.313     -35.056      11.227
# Government_Integrity     0.5150      0.057      9.052      0.000       0.403       0.626
# Government_Spending     -0.3622      0.040     -9.013      0.000      -0.441      -0.283
# Investment_Freedom       0.3449      0.066      5.210      0.000       0.215       0.475
# INV_Score                0.8400      0.389      2.157      0.031       0.077       1.603
# ==============================================================================
# Omnibus:                       45.891   Durbin-Watson:                   2.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.122
# Skew:                           1.023   Prob(JB):                     1.22e-24
# Kurtosis:                       6.027   Cond. No.                         700.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %% [markdown]
# # Série Temporal

# %%
# Série temporal simples

## Pegando os dados de um país, por exemplo, South Africa

df_time = df_panel.loc['South Africa']
df_time
# Out:
#             RLE_Score  Property_Rights  Judicial_Effectiveness  \
# Year
# 2019-01-01       58.3             58.8                    39.3
# 2019-01-01       58.3             58.8                    39.3
# 2019-01-01       58.3             58.8                    39.3
# 2019-01-01       58.3             58.8                    39.3
# 2018-01-01       63.0             67.7                    65.9
# 2018-01-01       63.0             67.7                    65.9
# 2018-01-01       63.0             67.7                    65.9
# 2018-01-01       63.0             67.7                    65.9
# 2017-01-01       62.3             67.6                    59.7
# 2017-01-01       62.3             67.6                    59.7
# 2017-01-01       62.3             67.6                    59.7
# 2017-01-01       62.3             67.6                    59.7
#
#             Government_Integrity  Tax_Burden  Government_Spending  \
# Year
# 2019-01-01                  39.7        62.1                 67.6
# 2019-01-01                  39.7        62.1                 67.6
# 2019-01-01                  39.7        62.1                 67.6
# 2019-01-01                  39.7        62.1                 67.6
# 2018-01-01                  45.4        62.5                 68.1
# 2018-01-01                  45.4        62.5                 68.1
# 2018-01-01                  45.4        62.5                 68.1
# 2018-01-01                  45.4        62.5                 68.1
# 2017-01-01                  47.6        70.2                 68.4
# 2017-01-01                  47.6        70.2                 68.4
# 2017-01-01                  47.6        70.2                 68.4
# 2017-01-01                  47.6        70.2                 68.4
#
#             Fiscal_Health  Business_Freedom  Labor_Freedom  Monetary_Freedom  \
# Year
# 2019-01-01           62.6              64.3           59.1              75.2
# 2019-01-01           62.6              64.3           59.1              75.2
# 2019-01-01           62.6              64.3           59.1              75.2
# 2019-01-01           62.6              64.3           59.1              75.2
# 2018-01-01           74.6              65.1           60.1              74.6
# 2018-01-01           74.6              65.1           60.1              74.6
# 2018-01-01           74.6              65.1           60.1              74.6
# 2018-01-01           74.6              65.1           60.1              74.6
# 2017-01-01           70.0              62.0           58.9              75.8
# 2017-01-01           70.0              62.0           58.9              75.8
# 2017-01-01           70.0              62.0           58.9              75.8
# 2017-01-01           70.0              62.0           58.9              75.8
#
#             Trade_Freedom  Investment_Freedom  Financial_Freedom  \
# Year
# 2019-01-01           76.0                45.0               50.0
# 2019-01-01           76.0                45.0               50.0
# 2019-01-01           76.0                45.0               50.0
# 2019-01-01           76.0                45.0               50.0
# 2018-01-01           71.6                50.0               50.0
# 2018-01-01           71.6                50.0               50.0
# 2018-01-01           71.6                50.0               50.0
# 2018-01-01           71.6                50.0               50.0
# 2017-01-01           77.3                40.0               50.0
# 2017-01-01           77.3                40.0               50.0
# 2017-01-01           77.3                40.0               50.0
# 2017-01-01           77.3                40.0               50.0
#
#             Productivity  INV_Score
# Year
# 2019-01-01     17.969189  15.417722
# 2019-01-01     17.969189  22.197563
# 2019-01-01     17.969189  22.197563
# 2019-01-01     17.969189  22.201323
# 2018-01-01     17.883596  15.944577
# 2018-01-01     17.883596  20.566652
# 2018-01-01     17.883596  20.566652
# 2018-01-01     17.883596  20.569805
# 2017-01-01     18.054855  16.398805
# 2017-01-01     18.054855  21.411327
# 2017-01-01     18.054855  21.411327
# 2017-01-01     18.054855  21.414621

# %% [markdown]
# ## O que é uma Série Temporal?
#
# Uma série temporal é uma sequência de observações de uma variável ao longo do tempo. Elas são amplamente utilizadas em previsões e análises de tendências em diversas áreas, como economia, finanças e meteorologia.
#
# ## Principais Conceitos
#
# - **Tendência**: É a direção geral em que os dados estão se movendo ao longo do tempo.
# - **Sazonalidade**: São padrões que se repetem em intervalos regulares de tempo.
# - **Ciclos**: São flutuações de longo prazo que não são sazonais.
# - **Ruído**: São variações aleatórias nos dados que não podem ser explicadas por tendências, sazonalidades ou ciclos.

# %%
## Fazendo a regressão da produtividade em função da integridade do governo

X = df_time[['Government_Integrity', 'Government_Spending', 'Investment_Freedom', 'INV_Score']]
y = df_time['Productivity']

X = sm.add_constant(X)

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Productivity   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.603e+25
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):          7.39e-101
# Time:                        11:10:42   Log-Likelihood:                 362.09
# No. Observations:                  12   AIC:                            -716.2
# Df Residuals:                       8   BIC:                            -714.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0046   4.11e-17   1.12e+14      0.000       0.005       0.005
# Government_Integrity    -0.0279   2.31e-15  -1.21e+13      0.000      -0.028      -0.028
# Government_Spending      0.2918   2.47e-15   1.18e+14      0.000       0.292       0.292
# Investment_Freedom      -0.0145   1.72e-15  -8.45e+12      0.000      -0.015      -0.015
# INV_Score                     0    2.8e-15          0      1.000   -6.45e-15    6.45e-15
# ==============================================================================
# Omnibus:                        5.355   Durbin-Watson:                   0.003
# Prob(Omnibus):                  0.069   Jarque-Bera (JB):                2.125
# Skew:                           0.707   Prob(JB):                        0.346
# Kurtosis:                       1.500   Cond. No.                     8.18e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.62e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\guian\Indicium\treinamentos\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=12 observations were given.
#   return hypotest_fun_in(*args, **kwds)
